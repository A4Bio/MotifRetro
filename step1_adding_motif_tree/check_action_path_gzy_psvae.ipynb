# %%
import sys; sys.path.append("/gaozhangyang/experiments/MotifRetro")
import pandas as pd
from rdkit import Chem
import json
import copy
from src.feat.utils import atom_to_edit_tuple, get_bond_tuple, fix_incomplete_mappings, reac_to_canonical, fix_explicit_hs, renumber_atoms_for_mapping, mark_reactants
from src.utils.chem_utils import mol2smi, smi2mol, compare_smis
from rdkit.Chem import Draw
from src.feat.reaction_actions import StopAction, AddMotifAction
from tqdm import tqdm
import numpy as np
from src.feat.featurize_gzy_psvae import ReactionSampleGenerator as ReactionSampleGenerator_gzy
import json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_115684/202284177.py in <module>
#       5 import copy
#       6 from src.feat.utils import atom_to_edit_tuple, get_bond_tuple, fix_incomplete_mappings, reac_to_canonical, fix_explicit_hs, renumber_atoms_for_mapping, mark_reactants
# ----> 7 from src.utils.chem_utils import mol2smi, smi2mol, compare_smis
#       8 from rdkit.Chem import Draw
#       9 from src.feat.reaction_actions import StopAction, AddMotifAction
#
# ImportError: cannot import name 'compare_smis' from 'src.utils.chem_utils' (/gaozhangyang/experiments/MotifRetro/src/utils/chem_utils.py)

# %%
# utils
action_vocab = json.load(open("/gaozhangyang/experiments/MotifRetro/data/uspto_50k/feat/uspto_50k_frag/action_vocab.json", 'r'))

props = action_vocab['prop2oh']
prop2oh = {'atom': {}, 'bond': {}}

for type_key in prop2oh.keys():
    oh_dict = props[type_key]
    for key, values in oh_dict.items():
        converted_values = {}
        for prop_val, val_oh in values.items():
            try:
                prop_val = int(prop_val)
            except ValueError:
                pass
            converted_values[prop_val] = val_oh
        prop2oh[type_key][key] = converted_values

action_vocab['prop2oh'] = prop2oh

def preprocess_mols(target, source):
    target_mol = Chem.MolFromSmiles(target)
    source_mol = Chem.MolFromSmiles(source)

    target_mol, source_mol = fix_incomplete_mappings(target_mol, source_mol)
    target_mol, source_mol = reac_to_canonical(target_mol, source_mol) 
    source_mol = fix_explicit_hs(source_mol)
    target_mol = fix_explicit_hs(target_mol)
    source_mol = renumber_atoms_for_mapping(source_mol)
    target_mol = renumber_atoms_for_mapping(target_mol)
    return target_mol, source_mol

# visualization
from rdkit import Chem
from rdkit.Chem.Draw import rdMolDraw2D, MolsToGridImage

drawOptions = rdMolDraw2D.MolDrawOptions()
drawOptions.prepareMolsBeforeDrawing = False
drawOptions.bondLineWidth = 4
drawOptions.minFontSize = 12


def prepare_mol(mol, new_am):
    highlight_idx = []
    for i, atom in enumerate(mol.GetAtoms()):
        am = atom.GetAtomMapNum()
        if am in new_am:
            highlight_idx.append(i)
            
    try:
        mol_draw = rdMolDraw2D.PrepareMolForDrawing(mol)
    except Chem.KekulizeException:
        mol_draw = rdMolDraw2D.PrepareMolForDrawing(mol, kekulize=False)
        # Chem.SanitizeMol(mol_draw, Chem.SANITIZE_ALL ^ Chem.SANITIZE_KEKULIZE)
    
    
    return mol_draw, highlight_idx

def plot_states(states, target_mol, source_mol):
    target_am = set([atom.GetAtomMapNum() for atom in  target_mol.GetAtoms()])
    source_am = set([atom.GetAtomMapNum() for atom in  source_mol.GetAtoms()])
    new_am = list(target_am - source_am)

    mol_list = []
    highlightAtomLists = []
    for one in states:
        mol, highlight = prepare_mol(one, new_am)
        mol_list.append(mol)
        highlightAtomLists.append(highlight)

    return MolsToGridImage(mol_list, molsPerRow=5,  subImgSize=(500, 500), drawOptions=drawOptions, highlightBondLists = highlightAtomLists)


# get edit states
def get_edit_sates(sample_generator):
    state = [copy.deepcopy(sample_generator.source_mol)]

    for i in range(100):
        reaction_action = sample_generator.generate_gen_action()
        print(reaction_action)
        if type(reaction_action)==StopAction:
            break
        
        sample_generator.source_mol = reaction_action.apply(sample_generator.source_mol) # 这是关键部分
        latent_mol = copy.deepcopy(sample_generator.source_mol)
        latent_mol.UpdatePropertyCache(strict=False)
        state.append(latent_mol)
    state.append(sample_generator.target_mol)
    return state

def fix_explicit_hs(mol):
    for a in mol.GetAtoms():
        a.SetNoImplicit(False)

    mol = Chem.AddHs(mol, explicitOnly=True)
    mol = Chem.RemoveHs(mol)

    Chem.SanitizeMol(mol)
    return mol

def mol2smi(mol, rm_am=False, fixH = False):
    mol = copy.deepcopy(mol)
    if fixH:
        mol = fix_explicit_hs(mol)
    if rm_am:
        for atom in mol.GetAtoms():
            atom.SetAtomMapNum(0)
    return Chem.MolToSmiles(mol)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_115684/1049887111.py in <module>
#       1 # utils
# ----> 2 action_vocab = json.load(open("/gaozhangyang/experiments/MotifRetro/data/uspto_50k/feat/uspto_50k_frag/action_vocab.json", 'r'))
#       3
#       4 props = action_vocab['prop2oh']
#       5 prop2oh = {'atom': {}, 'bond': {}}
#
# NameError: name 'json' is not defined

# %%
data = pd.read_csv("/gaozhangyang/experiments/MotifRetro/data/uspto_50k/raw_train.csv", index_col=0)

# data = pd.read_csv("/gaozhangyang/experiments/MotifRetro/data/uspto_full/USPTO_FULL_train.csv", index_col=0)

# print("cover rate {}".format((data['edit_len']<40).sum()/len(data)))
# data = data[data['edit_len']<40]

# length_array = np.array(data['edit_len'])

# print(length_array.mean(), length_array.max(), length_array.min())

# %%
long_path_idx = []
for idx in range(len(data)):

    target, source = data.iloc[idx]["reactants>reagents>production"].split(">>")
    # target, source = data.iloc[7]["rxn_smiles"].split(">>")

    target_mol, source_mol = preprocess_mols(target, source)


    vocab_path = "/gaozhangyang/experiments/MotifRetro/data/uspto_50k/adding_motif_trees.json"



    motifretro_sample_generator = ReactionSampleGenerator_gzy(Chem.rdchem.RWMol(source_mol), target_mol,  action_vocab=action_vocab, keep_actions_list=None, use_motif_action=True, vocab_path=vocab_path)

    motifretro_states = get_edit_sates(motifretro_sample_generator)
    if len(motifretro_states)>5:
        long_path_idx.append(idx)
    
    assert compare_smis(mol2smi(motifretro_states[-2]), mol2smi(motifretro_states[-1]))

plot_states(motifretro_states, target_mol, source_mol)
# Out:
# Add Motif [*:1][C:28](=[O:29])[O:30][CH2:31][c:32]1[cH:33][cH:34][cH:35][cH:36][cH:37]1
# Stop
# Delete bond (1, 20)
# Add Motif [*:1][OH:31]
# Stop
# Delete bond (1, 44)
# Add Motif [*:1]=[O:49]
# Stop
# Delete bond (1, 6)
# Add Motif [*:1]=[O:65]
# Stop
# Delete bond (1, 9)
# Add Motif [*:1][Cl:35]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:29]
# Add Motif [*:2][B:26]([OH:27])[OH:28]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:43]
# Add Motif [*:2][B:34]1[O:35][C:36]([CH3:37])([CH3:38])[C:39]([CH3:40])([CH3:41])[O:42]1
# Stop
# Edit bond (7, 8): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][OH:20]
# Stop
# Delete bond (1, 20)
# Add Motif [*:1][Br:30]
# Stop
# Add Motif [*:1][C:21]([CH3:22])([CH3:23])[CH3:24]
# Stop
# Edit Atom 1: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=Yes
# Add Motif [*:1][CH3:23]
# Add Motif [*:23][c:24]1[cH:25][cH:26][cH:27][cH:30][cH:31]1
# Add Motif [*:27][O:28][CH3:29]
# Stop
# Delete bond (1, 36)
# Add Motif [*:1][OH:42]
# Stop
# Delete bond (1, 7)
# Add Motif [*:1]=[O:21]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1][Br:17]
# Stop
# Add Motif [*:1][CH3:21]
# Stop
# Delete bond (1, 10)
# Add Motif [*:1][Cl:34]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:22]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:12]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:31]
# Stop
# Add Motif [*:1][CH2:21][c:22]1[cH:23][cH:24][cH:25][cH:26][cH:27]1
# Stop
# Delete bond (1, 21)
# Add Motif [*:1]=[O:28]
# Stop
# Delete bond (1, 18)
# Edit Atom 18: Formal Charge=-1, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1][Br:20]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][Br:12]
# Stop
# Add Motif [*:1][Si:23]([CH3:24])([CH3:25])[CH3:26]
# Stop
# Delete bond (1, 5)
# Add Motif [*:1][Cl:22]
# Stop
# Delete bond (19, 20)
# Edit bond (20, 22): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:28]
# Stop
# Delete bond (1, 21)
# Add Motif [*:1][OH:33]
# Stop
# Add Motif [*:1][CH3:28]
# Stop
# Delete bond (1, 14)
# Add Motif [*:1][OH:28]
# Stop
# Delete bond (1, 9)
# Delete bond (2, 6)
# Edit bond (1, 2): Bond Type=Double, Bond Stereo=None
# Edit bond (6, 7): Bond Type=Double, Bond Stereo=None
# Edit bond (7, 8): Bond Type=Single, Bond Stereo=None
# Edit bond (8, 9): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 10)
# Add Motif [*:1]=[O:35]
# Add Motif [*:10]=[P:16][c:17]1[cH:18][cH:19][cH:20][cH:21][cH:22]1
# Add Motif [*:16][c:23]1[cH:24][cH:25][cH:26][cH:27][cH:28]1
# Add Motif [*:16][c:29]1[cH:30][cH:31][cH:32][cH:33][cH:34]1
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:37]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1]=[O:18]
# Stop
# Delete bond (1, 18)
# Add Motif [*:1][OH:21]
# Stop
# Delete bond (1, 26)
# Add Motif [*:1][Br:32]
# Stop
# Delete bond (1, 15)
# Add Motif [*:1][Cl:30]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:23]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1]=[O:36]
# Stop
# Delete bond (1, 10)
# Add Motif [*:1][Cl:34]
# Stop
# Delete bond (1, 36)
# Add Motif [*:1][OH:43]
# Stop
# Delete bond (1, 16)
# Add Motif [*:1][Cl:35]
# Stop
# Delete bond (1, 4)
# Add Motif [*:1][Cl:12]
# Stop
# Delete bond (6, 8)
# Add Motif [*:6][O:32][C:33]([O:34][C:35]([CH3:36])([CH3:37])[CH3:38])=[O:39]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][Cl:45]
# Stop
# Delete bond (1, 36)
# Add Motif [*:1][OH:39]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][I:20]
# Add Motif [*:2][B:21]([OH:22])[OH:23]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][Cl:19]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:30]
# Stop
# Delete bond (15, 21)
# Edit bond (15, 16): Bond Type=Double, Bond Stereo=None
# Edit Atom 15: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Stop
# Edit Atom 1: Formal Charge=+1, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1](=[O:13])[O-:14]
# Stop
# Delete bond (8, 9)
# Edit bond (9, 11): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 12)
# Add Motif [*:1][Cl:41]
# Stop
# Delete bond (1, 26)
# Edit Atom 27: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Edit Atom 38: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Add Motif [*:1][OH:45]
# Stop
# Delete bond (1, 37)
# Add Motif [*:1][O:40][CH2:41][CH3:42]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:38]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:30]
# Add Motif [*:2][B:27]([OH:28])[OH:29]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:39]
# Stop
# Delete bond (1, 29)
# Add Motif [*:1][OH:35]
# Stop
# Delete bond (1, 17)
# Add Motif [*:1][OH:36]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][N:13]1[C:14](=[O:15])[CH2:16][CH2:17][C:18]1=[O:19]
# Stop
# Add Motif [*:1][CH3:32]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][O:19][S:20](=[O:21])(=[O:22])[C:23]([F:24])([F:25])[F:26]
# Add Motif [*:2][B:27]([OH:28])[OH:29]
# Stop
# Delete bond (15, 16)
# Edit bond (16, 17): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:19]
# Stop
# Delete bond (1, 5)
# Add Motif [*:1][Cl:11]
# Stop
# Delete bond (1, 21)
# Add Motif [*:1][OH:29]
# Add Motif [*:29][CH3:30]
# Add Motif [*:30][C:31]([F:32])([F:33])[F:34]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:33]
# Stop
# Delete bond (1, 2)
# Edit Atom 2: Formal Charge=+1, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 3: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Add Motif [*:1][F:17]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:53]
# Add Motif [*:2][B:54]([OH:55])[OH:56]
# Stop
# Add Motif [*:1][CH2:27][CH3:28]
# Stop
# Delete bond (1, 24)
# Add Motif [*:1][O:25][CH3:26]
# Stop
# Edit bond (1, 2): Bond Type=Double, Bond Stereo=None
# Stop
# Add Motif [*:1][C:21]([O:22][C:23]([CH3:24])([CH3:25])[CH3:26])=[O:27]
# Stop
# Delete bond (1, 4)
# Edit Atom 4: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][Br:17]
# Stop
# Edit Atom 1: Formal Charge=+1, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1](=[O:27])[O-:28]
# Stop
# Delete bond (1, 10)
# Add Motif [*:1][Cl:20]
# Stop
# Delete bond (1, 6)
# Add Motif [*:1][Br:25]
# Stop
# Delete bond (1, 10)
# Add Motif [*:1][OH:38]
# Stop
# Delete bond (4, 6)
# Edit bond (3, 4): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 28)
# Edit bond (1, 2): Bond Type=Double, Bond Stereo=None
# Stop
# Edit bond (1, 2): Bond Type=Double, Bond Stereo=None
# Add Motif [*:1][O:18][CH3:19]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1]=[O:12]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:27]
# Stop
# Delete bond (1, 21)
# Edit Atom 21: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][Cl:38]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][CH2:12][I:13]
# Add Motif [*:2][NH2:14]
# Stop
# Delete bond (1, 26)
# Add Motif [*:1][OH:27]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:37]
# Add Motif [*:2][B:38]1[O:39][C:40]([CH3:41])([CH3:42])[C:43]([CH3:44])([CH3:45])[O:46]1
# Stop
# Add Motif [*:1][Si:40]([C:41]([CH3:42])([CH3:43])[CH3:44])([CH3:45])[CH3:46]
# Stop
# Add Motif [*:1][Si:21]([C:22]([CH3:23])([CH3:24])[CH3:25])([CH3:26])[CH3:27]
# Stop
# Add Motif [*:1][CH3:18]
# Stop
# Add Motif [*:1][C:29]([O:30][C:31]([CH3:32])([CH3:33])[CH3:34])=[O:35]
# Stop
# Add Motif [*:1]=[O:21]
# Stop
# Add Motif [*:1][CH3:45]
# Stop
# Delete bond (1, 13)
# Add Motif [*:1][Cl:27]
# Stop
# Delete bond (1, 6)
# Add Motif [*:1][OH:22]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:31]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1][Br:40]
# Stop
# Add Motif [*:1][CH2:13][CH3:14]
# Stop
# Delete bond (1, 13)
# Add Motif [*:1][OH:19]
# Stop
# Delete bond (1, 21)
# Add Motif [*:1][OH:54]
# Stop
# Add Motif [*:1][C:20]([O:21][C:22]([CH3:23])([CH3:24])[CH3:25])=[O:26]
# Stop
# Delete bond (2, 4)
# Add Motif [*:2][O:31][C:32]([CH3:33])=[O:34]
# Stop
# Edit bond (11, 13): Bond Type=Double, Bond Stereo=None
# Stop
# Add Motif [*:1][CH3:33]
# Stop
# Add Motif [*:1][CH3:28]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1][Cl:19]
# Stop
# Delete bond (1, 4)
# Add Motif [*:1][Cl:17]
# Stop
# Add Motif [*:1][C:29]([CH3:30])([CH3:31])[CH3:32]
# Stop
# Add Motif [*:1][C:35]([O:36][C:37]([CH3:38])([CH3:39])[CH3:40])=[O:41]
# Stop
# Delete bond (1, 24)
# Add Motif [*:1][Br:38]
# Stop
# Delete bond (1, 4)
# Add Motif [*:1][OH:17]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:25]
# Stop
# Delete bond (1, 7)
# Add Motif [*:1][Br:28]
# Stop
# Delete bond (1, 2)
# Edit Atom 5: Formal Charge=0, Chiral Type=CCW, 1, Is Aromatic=No
# Add Motif [*:1][Cl:18]
# Stop
# Delete bond (1, 12)
# Add Motif [*:1][Br:35]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:25]
# Add Motif [*:2][I:24]
# Stop
# Delete bond (1, 2)
# Edit Atom 6: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Add Motif [*:1][Cl:34]
# Stop
# Delete bond (1, 2)
# Delete bond (1, 16)
# Add Motif [*:1]=[O:31]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:21]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:49]
# Stop
# Add Motif [*:1][C:29]([CH3:30])=[O:31]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1]=[O:24]
# Stop
# Delete bond (1, 25)
# Add Motif [*:1]=[O:38]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][I:32]
# Add Motif [*:2][B:29]([OH:30])[OH:31]
# Stop
# Delete bond (1, 8)
# Edit Atom 8: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][Br:22]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:30]
# Stop
# Delete bond (1, 26)
# Add Motif [*:1][OH:40]
# Stop
# Delete bond (1, 2)
# Edit Atom 3: Formal Charge=0, Chiral Type=CCW, 1, Is Aromatic=No
# Add Motif [*:1][F:35]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1]=[O:33]
# Add Motif [*:11][P+:14]([c:15]1[cH:16][cH:17][cH:18][cH:19][cH:20]1)([c:21]1[cH:22][cH:23][cH:24][cH:25][cH:26]1)[c:27]1[cH:28][cH:29][cH:30][cH:31][cH:32]1
# Stop
# Delete bond (1, 16)
# Add Motif [*:1][OH:33]
# Stop
# Delete bond (1, 2)
# Edit Atom 3: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Add Motif [*:1][Cl:32]
# Stop
# Delete bond (1, 2)
# Edit Atom 2: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][Br:23]
# Stop
# Delete bond (1, 5)
# Edit bond (1, 2): Bond Type=Double, Bond Stereo=None
# Edit bond (2, 3): Bond Type=Single, Bond Stereo=None
# Edit bond (3, 4): Bond Type=Single, Bond Stereo=None
# Edit bond (4, 5): Bond Type=Single, Bond Stereo=None
# Edit Atom 1: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 2: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 3: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 4: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 5: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:5]=[O:17]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:47]
# Add Motif [*:2][B:48]([OH:49])[OH:50]
# Stop
# Delete bond (1, 13)
# Add Motif [*:1][Cl:36]
# Stop
# Delete bond (1, 5)
# Add Motif [*:1][Cl:30]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:22]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:39]
# Add Motif [*:2][B:40]([OH:41])[OH:42]
# Stop
# Add Motif [*:1][C:16](=[O:17])[O:18][CH2:19][c:20]1[cH:21][cH:22][cH:23][cH:24][cH:25]1
# Stop
# Delete bond (1, 6)
# Add Motif [*:1][Sn:15]([CH2:16][CH2:17][CH2:18][CH3:19])([CH2:20][CH2:21][CH2:22][CH3:23])[CH2:24][CH2:25][CH2:26][CH3:27]
# Add Motif [*:6][Cl:28]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1][OH:31]
# Stop
# Edit Atom 1: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 12: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1][OH:29]
# Stop
# Delete bond (1, 19)
# Delete bond (10, 16)
# Edit bond (1, 10): Bond Type=Single, Bond Stereo=None
# Edit bond (16, 17): Bond Type=Double, Bond Stereo=None
# Edit bond (17, 19): Bond Type=Single, Bond Stereo=None
# Edit Atom 1: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 10: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 16: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 17: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 19: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:10][Br:20]
# Add Motif [*:1]=[O:21]
# Stop
# Delete bond (1, 13)
# Add Motif [*:1][Cl:19]
# Stop
# Delete bond (1, 15)
# Add Motif [*:1][OH:33]
# Stop
# Delete bond (1, 22)
# Edit Atom 23: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 24: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 30: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1][OH:33]
# Stop
# Add Motif [*:1]=[O:23]
# Stop
# Add Motif [*:1][CH3:25]
# Stop
# Edit Atom 1: Formal Charge=+1, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1](=[O:21])[O-:22]
# Stop
# Delete bond (1, 10)
# Add Motif [*:1][Cl:23]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:35]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:40]
# Stop
# Delete bond (1, 17)
# Add Motif [*:1][OH:40]
# Stop
# Add Motif [*:1][C:20]([CH3:21])=[O:22]
# Stop
# Delete bond (1, 18)
# Add Motif [*:1][Cl:31]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:15]
# Add Motif [*:2][N:12]([CH3:13])[CH3:14]
# Stop
# Delete bond (1, 9)
# Add Motif [*:1][Cl:16]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:31]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][Cl:38]
# Stop
# Delete bond (1, 4)
# Edit Atom 4: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][Cl:31]
# Stop
# Edit bond (5, 10): Bond Type=Aromatic, Bond Stereo=None
# Edit bond (6, 8): Bond Type=Aromatic, Bond Stereo=None
# Edit bond (8, 9): Bond Type=Aromatic, Bond Stereo=None
# Edit bond (9, 10): Bond Type=Aromatic, Bond Stereo=None
# Edit Atom 10: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Stop
# Add Motif [*:1]=[O:30]
# Stop
# Delete bond (1, 14)
# Add Motif [*:1][O:22][CH3:23]
# Stop
# Delete bond (1, 12)
# Add Motif [*:1][Cl:17]
# Stop
# Delete bond (1, 13)
# Edit Atom 14: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 17: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1][OH:37]
# Stop
# Add Motif [*:1][CH2:26][CH3:27]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1][Cl:27]
# Stop
# Delete bond (1, 11)
# Add Motif [*:1][Cl:29]
# Stop
# Delete bond (1, 6)
# Add Motif [*:1][Cl:25]
# Stop
# Delete bond (1, 5)
# Add Motif [*:1][Br:31]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:50]
# Stop
# Add Motif [*:1][C:12]([OH:13])=[O:15]
# Add Motif [*:13][CH3:14]
# Stop
# Add Motif [*:1][CH2:32][CH3:33]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:29]
# Add Motif [*:2][B:26]([OH:27])[OH:28]
# Stop
# Delete bond (1, 14)
# Add Motif [*:1]=[O:28]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:24]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:34]
# Stop
# Add Motif [*:1][C:31](=[O:32])[O:33][CH2:34][c:35]1[cH:36][cH:37][cH:38][cH:39][cH:40]1
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:33]
# Add Motif [*:2][B:34]([OH:35])[OH:36]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:23]
# Stop
# Delete bond (1, 6)
# Add Motif [*:1]=[O:27]
# Stop
# Delete bond (1, 6)
# Delete bond (1, 16)
# Edit bond (6, 7): Bond Type=Single, Bond Stereo=None
# Edit bond (15, 16): Bond Type=Single, Bond Stereo=None
# Edit Atom 1: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 6: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Edit Atom 16: Formal Charge=0, Chiral Type=None, 0, Is Aromatic=No
# Add Motif [*:1](=[O:17])[OH:18]
# Stop
# Delete bond (1, 14)
# Add Motif [*:1][Br:45]
# Stop
# Delete bond (1, 14)
# Add Motif [*:1][OH:35]
# Stop
# Delete bond (1, 25)
# Add Motif [*:1][OH:36]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:21]
# Stop
# Delete bond (1, 4)
# Add Motif [*:1][Br:14]
# Stop
# Delete bond (1, 6)
# Edit Atom 1: Formal Charge=0, Chiral Type=CW, 1, Is Aromatic=No
# Add Motif [*:1][OH:17]
# Stop
# Add Motif [*:1][CH2:13][c:14]1[cH:15][cH:16][cH:17][cH:18][cH:19]1
# Stop
# Add Motif [*:1][CH3:23]
# Stop
# Add Motif [*:1][C:23]([O:24][C:25]([CH3:26])([CH3:27])[CH3:28])=[O:29]
# Stop
# Add Motif [*:1][C:25]([O:26][C:27]([CH3:28])([CH3:29])[CH3:30])=[O:31]
# Stop
# Delete bond (1, 18)
# Edit Atom 18: Formal Charge=0, Chiral Type=None, 1, Is Aromatic=Yes
# Add Motif [*:1][O:43][S:44]([CH3:45])(=[O:46])=[O:47]
# Stop
# Delete bond (1, 9)
# Add Motif [*:1][Br:36]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:33]
# Stop
# Delete bond (1, 9)
# Add Motif [*:1][Cl:28]
# Stop
# Delete bond (1, 19)
# Add Motif [*:1][OH:28]
# Stop
# Delete bond (1, 8)
# Add Motif [*:1]=[O:24]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:17]
# Stop
# Delete bond (25, 26)
# Edit bond (26, 28): Bond Type=Double, Bond Stereo=None
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Br:48]
# Add Motif [*:2][B:40]1[O:41][CH2:42][CH2:43][CH2:46][O:47]1
# Add Motif [*:43][CH3:44]
# Add Motif [*:43][CH3:45]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][Cl:30]
# Stop
# Delete bond (1, 24)
# Add Motif [*:1][OH:30]
# Stop
# Delete bond (1, 2)
# Add Motif [*:1][F:34]
# Stop
# Delete bond (1, 2)
# Edit bond (2, 3): Bond Type=Double, Bond Stereo=None
# Add Motif [*:1][Mg+:27]
# Stop
# Edit bond (11, 12): Bond Type=Double, Bond Stereo=None
# Stop
# Add Motif [*:1]1[c:20](=[O:21])[c:22]2[cH:23][cH:24][cH:25][cH:26][c:27]2[c:28]1=[O:29]
# Stop
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# /tmp/ipykernel_92617/770030184.py in <module>
#      18         long_path_idx.append(idx)
#      19
# ---> 20     assert compare_smis(mol2smi(motifretro_states[-2]), mol2smi(motifretro_states[-1]))
#      21
#      22 plot_states(motifretro_states, target_mol, source_mol)
#
# /gaozhangyang/experiments/MotifRetro/src/utils/chem_utils.py in compare_smis(smi1, smi2)
#     265
#     266 def compare_smis(smi1, smi2):
# --> 267     smi1 = Chem.CanonSmiles(smi1.replace("@@", "@").replace("@", ""))
#     268     smi2 = Chem.CanonSmiles(smi2.replace("@@", "@").replace("@", ""))
#     269     return smi1 == smi2
#
# ~/anaconda3/envs/equibind/lib/python3.7/site-packages/rdkit/Chem/__init__.py in CanonSmiles(smi, useChiral)
#      55 def CanonSmiles(smi, useChiral=1):
#      56   m = MolFromSmiles(smi)
# ---> 57   return MolToSmiles(m, useChiral)
#      58
#      59
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolfiles.MolToSmiles(NoneType, int)
# did not match C++ signature:
#     MolToSmiles(RDKit::ROMol mol, bool isomericSmiles=True, bool kekuleSmiles=False, int rootedAtAtom=-1, bool canonical=True, bool allBondsExplicit=False, bool allHsExplicit=False, bool doRandom=False)
#     MolToSmiles(RDKit::ROMol mol, RDKit::SmilesWriteParams params)

# %%
idx
# Out:
# 208

# %%
mol2smi(motifretro_states[-1])
# Out:
# '[NH3+:2][C@H:3]([CH3:4])[CH:5]1[CH2:6][CH2:7][O:8][CH2:9][CH2:10]1.[c:1]1([F:17])[n:11][cH:12][cH:13][cH:14][c:15]1[I:16]'

# %%
# Out:
# True
